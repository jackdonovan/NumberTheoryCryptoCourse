# %%
# This is problem 1a
N = 176837
B = 10
a = 2
for j in [1..B]:
    a = power_mod(a,j,N)
    d = gcd(a - 1,N)
    print 'j =',j, '\t| a^(j!)  =  ',a, '\t| gcd(a^(j!) - 1,N)  = ',d
# Out:
# j = 1 	| a^(j!)  =   2 	| gcd(a^(j!) - 1,N)  =  1
# j = 2 	| a^(j!)  =   4 	| gcd(a^(j!) - 1,N)  =  1
# j = 3 	| a^(j!)  =   64 	| gcd(a^(j!) - 1,N)  =  1
# j = 4 	| a^(j!)  =   154538 	| gcd(a^(j!) - 1,N)  =  1
# j = 5 	| a^(j!)  =   96786 	| gcd(a^(j!) - 1,N)  =  1
# j = 6 	| a^(j!)  =   64799 	| gcd(a^(j!) - 1,N)  =  181
# j = 7 	| a^(j!)  =   120185 	| gcd(a^(j!) - 1,N)  =  181
# j = 8 	| a^(j!)  =   124348 	| gcd(a^(j!) - 1,N)  =  181
# j = 9 	| a^(j!)  =   160729 	| gcd(a^(j!) - 1,N)  =  181
# j = 10 	| a^(j!)  =   161272 	| gcd(a^(j!) - 1,N)  =  181

# %%
# problem 1b
N = 2992427
B = 15
a = 2
for j in [1..B]:
    a = power_mod(a,j,N)
    d = gcd(a - 1,N)
    print 'j =',j, '\t| a^(j!)  =  ',a, '\t| gcd(a^(j!) - 1,N)  = ',d
# Out:
# j = 1 	| a^(j!)  =   2 	| gcd(a^(j!) - 1,N)  =  1
# j = 2 	| a^(j!)  =   4 	| gcd(a^(j!) - 1,N)  =  1
# j = 3 	| a^(j!)  =   64 	| gcd(a^(j!) - 1,N)  =  1
# j = 4 	| a^(j!)  =   1815081 	| gcd(a^(j!) - 1,N)  =  1
# j = 5 	| a^(j!)  =   902388 	| gcd(a^(j!) - 1,N)  =  1
# j = 6 	| a^(j!)  =   498659 	| gcd(a^(j!) - 1,N)  =  1
# j = 7 	| a^(j!)  =   463865 	| gcd(a^(j!) - 1,N)  =  2521
# j = 8 	| a^(j!)  =   2042011 	| gcd(a^(j!) - 1,N)  =  2521
# j = 9 	| a^(j!)  =   1578147 	| gcd(a^(j!) - 1,N)  =  2521
# j = 10 	| a^(j!)  =   486554 	| gcd(a^(j!) - 1,N)  =  2521
# j = 11 	| a^(j!)  =   2891588 	| gcd(a^(j!) - 1,N)  =  2521
# j = 12 	| a^(j!)  =   1837810 	| gcd(a^(j!) - 1,N)  =  2521
# j = 13 	| a^(j!)  =   1215123 	| gcd(a^(j!) - 1,N)  =  2521
# j = 14 	| a^(j!)  =   2548732 	| gcd(a^(j!) - 1,N)  =  2521
# j = 15 	| a^(j!)  =   2357136 	| gcd(a^(j!) - 1,N)  =  2521

# %%
# problem 2a
N = 2694794017
B = 15
a = 2
for j in [1..B]:
    a = power_mod(a,j,N)
    d = gcd(a - 1,N)
    print 'j =',j, '\t| a^(j!)  =  ',a, '\t| gcd(a^(j!) - 1,N)  = ',d
# Out:
# j = 1 	| a^(j!)  =   2 	| gcd(a^(j!) - 1,N)  =  1
# j = 2 	| a^(j!)  =   4 	| gcd(a^(j!) - 1,N)  =  1
# j = 3 	| a^(j!)  =   64 	| gcd(a^(j!) - 1,N)  =  1
# j = 4 	| a^(j!)  =   16777216 	| gcd(a^(j!) - 1,N)  =  1
# j = 5 	| a^(j!)  =   894795572 	| gcd(a^(j!) - 1,N)  =  1
# j = 6 	| a^(j!)  =   622655793 	| gcd(a^(j!) - 1,N)  =  1
# j = 7 	| a^(j!)  =   2488872917 	| gcd(a^(j!) - 1,N)  =  1
# j = 8 	| a^(j!)  =   2234817438 	| gcd(a^(j!) - 1,N)  =  1
# j = 9 	| a^(j!)  =   631260516 	| gcd(a^(j!) - 1,N)  =  1
# j = 10 	| a^(j!)  =   2302678859 	| gcd(a^(j!) - 1,N)  =  1
# j = 11 	| a^(j!)  =   2558738324 	| gcd(a^(j!) - 1,N)  =  1
# j = 12 	| a^(j!)  =   285773601 	| gcd(a^(j!) - 1,N)  =  51031
# j = 13 	| a^(j!)  =   1145186672 	| gcd(a^(j!) - 1,N)  =  51031
# j = 14 	| a^(j!)  =   1570938305 	| gcd(a^(j!) - 1,N)  =  51031
# j = 15 	| a^(j!)  =   2591711398 	| gcd(a^(j!) - 1,N)  =  51031

# %%
# problem 2b
N = 715027643089
B = 317
a = 2
for j in [1..B]:
    a = power_mod(a,j,N)
    d = gcd(a - 1,N)
    print 'j =',j, '\t| a^(j!)  =  ',a, '\t| gcd(a^(j!) - 1,N)  = ',d
# Out:
# j = 1 	| a^(j!)  =   2 	| gcd(a^(j!) - 1,N)  =  1
# j = 2 	| a^(j!)  =   4 	| gcd(a^(j!) - 1,N)  =  1
# j = 3 	| a^(j!)  =   64 	| gcd(a^(j!) - 1,N)  =  1
# j = 4 	| a^(j!)  =   16777216 	| gcd(a^(j!) - 1,N)  =  1
# j = 5 	| a^(j!)  =   211427600303 	| gcd(a^(j!) - 1,N)  =  1
# j = 6 	| a^(j!)  =   646693800688 	| gcd(a^(j!) - 1,N)  =  1
# j = 7 	| a^(j!)  =   356917881025 	| gcd(a^(j!) - 1,N)  =  1
# j = 8 	| a^(j!)  =   574052693182 	| gcd(a^(j!) - 1,N)  =  1
# j = 9 	| a^(j!)  =   97212642619 	| gcd(a^(j!) - 1,N)  =  1
# j = 10 	| a^(j!)  =   211787713493 	| gcd(a^(j!) - 1,N)  =  1
# j = 11 	| a^(j!)  =   589194037048 	| gcd(a^(j!) - 1,N)  =  1
# j = 12 	| a^(j!)  =   1466762615 	| gcd(a^(j!) - 1,N)  =  1
# j = 13 	| a^(j!)  =   632162525804 	| gcd(a^(j!) - 1,N)  =  1
# j = 14 	| a^(j!)  =   179714937925 	| gcd(a^(j!) - 1,N)  =  1
# j = 15 	| a^(j!)  =   451805057034 	| gcd(a^(j!) - 1,N)  =  1
# j = 16 	| a^(j!)  =   37752549502 	| gcd(a^(j!) - 1,N)  =  1
# ...

# %%
# problem 2c
N = 63598690279
B = 733
a = 2
for j in [1..B]:
    a = power_mod(a,j,N)
    d = gcd(a - 1,N)
    print 'j =',j, '\t| a^(j!)  =  ',a, '\t| gcd(a^(j!) - 1,N)  = ',d
# Out:
# j = 1 	| a^(j!)  =   2 	| gcd(a^(j!) - 1,N)  =  1
# j = 2 	| a^(j!)  =   4 	| gcd(a^(j!) - 1,N)  =  1
# j = 3 	| a^(j!)  =   64 	| gcd(a^(j!) - 1,N)  =  1
# j = 4 	| a^(j!)  =   16777216 	| gcd(a^(j!) - 1,N)  =  1
# j = 5 	| a^(j!)  =   24370587645 	| gcd(a^(j!) - 1,N)  =  1
# j = 6 	| a^(j!)  =   41339413977 	| gcd(a^(j!) - 1,N)  =  1
# j = 7 	| a^(j!)  =   57073176058 	| gcd(a^(j!) - 1,N)  =  1
# j = 8 	| a^(j!)  =   47739046770 	| gcd(a^(j!) - 1,N)  =  1
# j = 9 	| a^(j!)  =   33952289391 	| gcd(a^(j!) - 1,N)  =  1
# j = 10 	| a^(j!)  =   12949631213 	| gcd(a^(j!) - 1,N)  =  1
# j = 11 	| a^(j!)  =   11730768772 	| gcd(a^(j!) - 1,N)  =  1
# j = 12 	| a^(j!)  =   5361976356 	| gcd(a^(j!) - 1,N)  =  1
# j = 13 	| a^(j!)  =   40784061892 	| gcd(a^(j!) - 1,N)  =  1
# j = 14 	| a^(j!)  =   6911457954 	| gcd(a^(j!) - 1,N)  =  1
# j = 15 	| a^(j!)  =   55195955481 	| gcd(a^(j!) - 1,N)  =  1
# j = 16 	| a^(j!)  =   7579824800 	| gcd(a^(j!) - 1,N)  =  1
# ...

# %%
# problem 2d

# problem 2b
N = 69222671828129289159849427930209176172447705299
B = 5
a = 2
for j in [1..B]:
    a = power_mod(a,j,N)
    d = gcd(a - 1,N)
    print 'j =',j, '\t| a^(j!)  =  ',a, '\t| gcd(a^(j!) - 1,N)  = ',d
# Out:
# j = 1 	| a^(j!)  =   2 	| gcd(a^(j!) - 1,N)  =  1
# j = 2 	| a^(j!)  =   4 	| gcd(a^(j!) - 1,N)  =  1
# j = 3 	| a^(j!)  =   64 	| gcd(a^(j!) - 1,N)  =  1
# j = 4 	| a^(j!)  =   16777216 	| gcd(a^(j!) - 1,N)  =  17
# j = 5 	| a^(j!)  =   1329227995784915872903807060280344576 	| gcd(a^(j!) - 1,N)  =  17

# %%
# problem 3
N = 186667899687091
B = 15
a = 2
for j in [1..B]:
    a = power_mod(a,j,N)
    d = gcd(a - 1,N)
    print 'j =',j, '\t| a^(j!)  =  ',a, '\t| gcd(a^(j!) - 1,N)  = ',d
# Out:
# j = 1 	| a^(j!)  =   2 	| gcd(a^(j!) - 1,N)  =  1
# j = 2 	| a^(j!)  =   4 	| gcd(a^(j!) - 1,N)  =  1
# j = 3 	| a^(j!)  =   64 	| gcd(a^(j!) - 1,N)  =  1
# j = 4 	| a^(j!)  =   16777216 	| gcd(a^(j!) - 1,N)  =  1
# j = 5 	| a^(j!)  =   9390547932934 	| gcd(a^(j!) - 1,N)  =  1
# j = 6 	| a^(j!)  =   158979807686358 	| gcd(a^(j!) - 1,N)  =  1
# j = 7 	| a^(j!)  =   69217596889026 	| gcd(a^(j!) - 1,N)  =  1
# j = 8 	| a^(j!)  =   24447240935797 	| gcd(a^(j!) - 1,N)  =  1
# j = 9 	| a^(j!)  =   99708511710963 	| gcd(a^(j!) - 1,N)  =  1
# j = 10 	| a^(j!)  =   68372971692804 	| gcd(a^(j!) - 1,N)  =  151201
# j = 11 	| a^(j!)  =   107072780399827 	| gcd(a^(j!) - 1,N)  =  151201
# j = 12 	| a^(j!)  =   29892684308832 	| gcd(a^(j!) - 1,N)  =  151201
# j = 13 	| a^(j!)  =   25371391719101 	| gcd(a^(j!) - 1,N)  =  151201
# j = 14 	| a^(j!)  =   116121998767159 	| gcd(a^(j!) - 1,N)  =  151201
# j = 15 	| a^(j!)  =   23650632257692 	| gcd(a^(j!) - 1,N)  =  151201

# %%
N/151201
# Out:
# 1234567891
